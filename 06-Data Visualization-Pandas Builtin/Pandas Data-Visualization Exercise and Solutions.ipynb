# %%
import pandas as pd
import matplotlib.pyplot as plt
df3 = pd.read_csv('df3')
# %matplotlib inline

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       500 non-null    float64
#  1   b       500 non-null    float64
#  2   c       500 non-null    float64
#  3   d       500 non-null    float64
# dtypes: float64(4)
# memory usage: 15.8 KB

# %% [markdown]
# #scatter plot of b vs a

# %%
df3.plot.scatter(x='a' , y ='b')
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df3.plot.scatter(x='a' , y ='b', figsize = (12,3))
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df3.plot.scatter(x='a' , y ='b', figsize = (12,3), c='red')
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
#Histogram of col a

# %%
df3['a'].hist()
# Out:
# <AxesSubplot:>

# %%
df3['a'].hist(bins = 20)
# Out:
# <AxesSubplot:>

# %%
#make plot more polished, Use style sheets to set the style to 'ggplot' and redo the histogram from above. Also figure out how to add  more bins in it

# %%
plt.style.use('ggplot')

# %%
df3['a'].plot.hist(bins = 20, alpha = 0.5)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
#create boxplot comparing a and b columns

# %%
df3.boxplot()
# Out:
# <AxesSubplot:>

# %%
df3.boxplot(x = 'a', y= 'b')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18112/3581109086.py in <module>
# ----> 1 df3.boxplot(x = 'a', y= 'b')
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, backend, **kwargs)
#     509 ):
#     510     plot_backend = _get_plot_backend(backend)
# --> 511     return plot_backend.boxplot_frame(
#     512         self,
#     513         column=column,
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\boxplot.py in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#     392     import matplotlib.pyplot as plt
#     393
# --> 394     ax = boxplot(
#     395         self,
#     396         column=column,
#
# ...

# %%
df3
# Out:
#             a         b         c         d
# 0    0.336272  0.325011  0.001020  0.401402
# 1    0.980265  0.831835  0.772288  0.076485
# 2    0.480387  0.686839  0.000575  0.746758
# 3    0.502106  0.305142  0.768608  0.654685
# 4    0.856602  0.171448  0.157971  0.321231
# ..        ...       ...       ...       ...
# 495  0.528705  0.226122  0.055835  0.131962
# 496  0.324730  0.215201  0.935302  0.794115
# 497  0.118036  0.264574  0.629206  0.824062
# 498  0.227021  0.660209  0.851353  0.478676
# 499  0.466157  0.753000  0.115391  0.279712
#
# [500 rows x 4 columns]

# %%
df3[['a', 'b']] #passing list of col name
# Out:
#             a         b
# 0    0.336272  0.325011
# 1    0.980265  0.831835
# 2    0.480387  0.686839
# 3    0.502106  0.305142
# 4    0.856602  0.171448
# ..        ...       ...
# 495  0.528705  0.226122
# 496  0.324730  0.215201
# 497  0.118036  0.264574
# 498  0.227021  0.660209
# 499  0.466157  0.753000
#
# [500 rows x 2 columns]

# %%
df3[['a', 'b']].boxplot()
# Out:
# <AxesSubplot:>

# %%
df3[['a', 'b']].plot.box()
# Out:
# <AxesSubplot:>

# %%
#create a kde plot of the 'd' column

# %%
df3['d'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df3['d'].plot.kde(lw = 5, ls='---')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18112/3673791832.py in <module>
# ----> 1 df3['d'].plot.kde(lw = S, ls='---')
#
# NameError: name 'S' is not defined
